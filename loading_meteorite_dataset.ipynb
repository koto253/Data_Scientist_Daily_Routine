# %% [markdown]
# <a href="https://colab.research.google.com/github/koto253/Data_Scientist_Daily_Routine/blob/main/loading_meteorite_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing Libraries
import pandas as pd

# %%
# Loading the dataset
df = pd.read_excel('/content/drive/MyDrive/Downloads/meteorite_dataset.xlsx')

# %%
df
# Out:
#                        Id   Fall   Id.1                   Name Nametype  \
# 0      row-hzx5-myxf_ktcf   Fell      1                 Aachen    Valid
# 1      row-rcr3.5w34_59cn   Fell      2                 Aarhus    Valid
# 2      row-gffa_citp-4gu8   Fell      6                   Abee    Valid
# 3      row-tw78-y449.cqkk   Fell     10               Acapulco    Valid
# 4      row-adit.5t7p.agsg   Fell    370                Achiras    Valid
# ...                   ...    ...    ...                    ...      ...
# 45711  row-nqs6-zpvi~4awi  Found  57427  Northwest Africa 7863    Valid
# 45712  row-engy-36sr-fqc8  Found  57422  Northwest Africa 7857    Valid
# 45713  row-6q2t-sfdp~2gbz  Found  57421  Northwest Africa 7856    Valid
# 45714  row-5sv8.knfu.bnae  Found  57166  Northwest Africa 7755    Valid
# 45715  row-aeqf~vfsw.v6x5  Found  57150  Northwest Africa 7701    Valid
#
#                     Recclass           Location                     Year  \
# ...
